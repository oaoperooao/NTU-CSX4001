# %%
import nltk
from nltk.tokenize import sent_tokenize, word_tokenize
from nltk.tokenize import TreebankWordTokenizer
from nltk.tag import pos_tag
from nltk import ne_chunk, Tree
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('maxent_ne_chunker')
nltk.download('words')
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\perot\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\perot\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package maxent_ne_chunker to
# [nltk_data]     C:\Users\perot\AppData\Roaming\nltk_data...
# [nltk_data]   Package maxent_ne_chunker is already up-to-date!
# [nltk_data] Downloading package words to
# [nltk_data]     C:\Users\perot\AppData\Roaming\nltk_data...
# [nltk_data]   Package words is already up-to-date!
# True

# %%
f = open('./path/news.txt','r')
ex = f.readlines()
f.close()
len(ex)
# Out:
# 44

# %%
strEx = " ".join(str(x) for x in ex)

# %%
def preprocess(sent):
    sent = nltk.word_tokenize(sent)
    sent = nltk.pos_tag(sent)
    return sent

# %%
sent = preprocess(strEx)
sent
# Out:
# [('Voters', 'NNS'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('have', 'VBP'),
#  ('rejected', 'VBN'),
#  ('same-sex', 'JJ'),
#  ('marriage', 'NN'),
#  ('in', 'IN'),
#  ('a', 'DT'),
#  ('referendum', 'NN'),
#  (',', ','),
#  ('a', 'DT'),
#  ('setback', 'NN'),
#  ('to', 'TO'),
#  ('LGBT', 'NNP'),
#  ('couples', 'NNS'),
#  ('hoping', 'VBG'),
#  ('their', 'PRP$'),
#  ('island', 'NN'),
#  ('will', 'MD'),
#  ('be', 'VB'),
#  ('the', 'DT'),
#  ('first', 'JJ'),
#  ('country', 'NN'),
#  ('in', 'IN'),
#  ('Asia', 'NNP'),
#  ('to', 'TO'),
#  ('let', 'VB'),
#  ('same-sex', 'JJ'),
#  ('couples', 'NNS'),
#  ('share', 'NN'),
#  ('child', 'JJ'),
#  ('custody', 'NN'),
#  ('and', 'CC'),
#  ('insurance', 'NN'),
#  ('benefits', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('vote', 'NN'),
#  ('on', 'IN'),
#  ('Saturday', 'NNP'),
#  (',', ','),
#  ('organised', 'VBN'),
#  ('by', 'IN'),
#  ('Christian', 'JJ'),
#  ('groups', 'NNS'),
#  ('that', 'WDT'),
#  ('make', 'VBP'),
#  ('up', 'RP'),
#  ('about', 'RB'),
#  ('5', 'CD'),
#  ('%', 'NN'),
#  ('of', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'POS'),
#  ('population', 'NN'),
#  ('and', 'CC'),
#  ('advocates', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('traditional', 'JJ'),
#  ('Chinese', 'JJ'),
#  ('family', 'NN'),
#  ('structure', 'NN'),
#  (',', ','),
#  ('contradicts', 'VBZ'),
#  ('a', 'DT'),
#  ('May', 'NNP'),
#  ('2017', 'CD'),
#  ('constitutional', 'JJ'),
#  ('court', 'NN'),
#  ('ruling', 'NN'),
#  ('.', '.'),
#  ('Justices', 'NNS'),
#  ('told', 'VBD'),
#  ('legislators', 'NNS'),
#  ('then', 'RB'),
#  ('to', 'TO'),
#  ('make', 'VB'),
#  ('same-sex', 'JJ'),
#  ('marriage', 'NN'),
#  ('legal', 'JJ'),
#  ('within', 'IN'),
#  ('two', 'CD'),
#  ('years', 'NNS'),
#  (',', ','),
#  ('a', 'DT'),
#  ('first', 'JJ'),
#  ('for', 'IN'),
#  ('Asia', 'NNP'),
#  (',', ','),
#  ('where', 'WRB'),
#  ('religion', 'NN'),
#  ('and', 'CC'),
#  ('conservative', 'JJ'),
#  ('governments', 'NNS'),
#  ('normally', 'RB'),
#  ('keep', 'VB'),
#  ('the', 'DT'),
#  ('bans', 'NNS'),
#  ('in', 'IN'),
#  ('place', 'NN'),
#  ('.', '.'),
#  ('Although', 'IN'),
#  ('the', 'DT'),
#  ('ballot', 'NN'),
#  ('is', 'VBZ'),
#  ('advisory', 'JJ'),
#  ('only', 'RB'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('is', 'VBZ'),
#  ('expected', 'VBN'),
#  ('to', 'TO'),
#  ('frustrate', 'VB'),
#  ('lawmakers', 'NNS'),
#  ('mindful', 'JJ'),
#  ('of', 'IN'),
#  ('public', 'JJ'),
#  ('opinion', 'NN'),
#  ('as', 'IN'),
#  ('they', 'PRP'),
#  ('face', 'VBP'),
#  ('the', 'DT'),
#  ('court', 'NN'),
#  ('deadline', 'NN'),
#  ('next', 'JJ'),
#  ('year', 'NN'),
#  ('.', '.'),
#  ('Many', 'JJ'),
#  ('legislators', 'NNS'),
#  ('will', 'MD'),
#  ('stand', 'VB'),
#  ('for', 'IN'),
#  ('re-election', 'NN'),
#  ('in', 'IN'),
#  ('2020', 'CD'),
#  ('.', '.'),
#  ('“', 'VB'),
#  ('The', 'DT'),
#  ('legislature', 'NN'),
#  ('has', 'VBZ'),
#  ('lots', 'NNS'),
#  ('of', 'IN'),
#  ('choices', 'NNS'),
#  ('on', 'IN'),
#  ('how', 'WRB'),
#  ('to', 'TO'),
#  ('make', 'VB'),
#  ('this', 'DT'),
#  ('court', 'NN'),
#  ('order', 'NN'),
#  ('take', 'VB'),
#  ('effect', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('said', 'VBD'),
#  ('referendum', 'JJ'),
#  ('proponent', 'NN'),
#  ('Chen', 'NNP'),
#  ('Ke', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('Catholic', 'NNP'),
#  ('pastor', 'NN'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('and', 'CC'),
#  ('an', 'DT'),
#  ('opponent', 'NN'),
#  ('of', 'IN'),
#  ('same-sex', 'JJ'),
#  ('marriage', 'NN'),
#  ('.', '.'),
#  ('Ruling', 'VBG'),
#  ('party', 'NN'),
#  ('lawmakers', 'NNS'),
#  ('backed', 'VBN'),
#  ('by', 'IN'),
#  ('president', 'NN'),
#  ('Tsai', 'NNP'),
#  ('Ing-wen', 'NNP'),
#  ('had', 'VBD'),
#  ('proposed', 'VBN'),
#  ('legalising', 'VBG'),
#  ('same-sex', 'JJ'),
#  ('marriage', 'NN'),
#  ('in', 'IN'),
#  ('late', 'JJ'),
#  ('2016', 'CD'),
#  (',', ','),
#  ('but', 'CC'),
#  ('put', 'VBD'),
#  ('aside', 'RP'),
#  ('their', 'PRP$'),
#  ('ideas', 'NNS'),
#  ('to', 'TO'),
#  ('await', 'VB'),
#  ('the', 'DT'),
#  ('court', 'NN'),
#  ('hearing', 'NN'),
#  ('.', '.'),
#  ('Opposition', 'NN'),
#  ('to', 'TO'),
#  ('same-sex', 'JJ'),
#  ('marriage', 'NN'),
#  ('crested', 'VBN'),
#  ('after', 'IN'),
#  ('the', 'DT'),
#  ('court', 'NN'),
#  ('ruling', 'NN'),
#  ('.', '.'),
#  ('Opponents', 'NNS'),
#  ('have', 'VBP'),
#  ('held', 'VBN'),
#  ('rallies', 'NNS'),
#  ('and', 'CC'),
#  ('mobilised', 'VBN'),
#  ('votes', 'NNS'),
#  ('online', 'VBP'),
#  ('.', '.'),
#  ('Courts', 'NNS'),
#  ('will', 'MD'),
#  ('still', 'RB'),
#  ('consider', 'VB'),
#  ('local', 'JJ'),
#  ('marriage-licensing', 'NN'),
#  ('offices', 'NNS'),
#  ('in', 'IN'),
#  ('violation', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('law', 'NN'),
#  ('if', 'IN'),
#  ('they', 'PRP'),
#  ('refuse', 'VBP'),
#  ('same-sex', 'JJ'),
#  ('couples', 'NNS'),
#  ('until', 'IN'),
#  ('May', 'NNP'),
#  ('2019', 'CD'),
#  (',', ','),
#  ('a', 'DT'),
#  ('Ministry', 'NNP'),
#  ('of', 'IN'),
#  ('Justice', 'NNP'),
#  ('spokesperson', 'NN'),
#  ('said', 'VBD'),
#  ('last', 'JJ'),
#  ('week', 'NN'),
#  ('.', '.'),
#  ('“', 'VB'),
#  ('The', 'DT'),
#  ('referendum', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('general', 'JJ'),
#  ('survey', 'NN'),
#  (',', ','),
#  ('it', 'PRP'),
#  ('doesn', 'VBZ'),
#  ('’', 'JJ'),
#  ('t', 'NNS'),
#  ('have', 'VBP'),
#  ('very', 'RB'),
#  ('strong', 'JJ'),
#  ('legal', 'JJ'),
#  ('implications', 'NNS'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('said', 'VBD'),
#  ('Shiau', 'NNP'),
#  ('Hong-chi', 'NNP'),
#  (',', ','),
#  ('a', 'DT'),
#  ('professor', 'NN'),
#  ('of', 'IN'),
#  ('gender', 'NN'),
#  ('studies', 'NNS'),
#  ('and', 'CC'),
#  ('communications', 'NNS'),
#  ('management', 'NN'),
#  ('at', 'IN'),
#  ('Shih-Hsin', 'NNP'),
#  ('University', 'NNP'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('.', '.'),
#  ('“', 'VB'),
#  ('One', 'CD'),
#  ('way', 'NN'),
#  ('or', 'CC'),
#  ('another', 'DT'),
#  ('it', 'PRP'),
#  ('has', 'VBZ'),
#  ('to', 'TO'),
#  ('go', 'VB'),
#  ('back', 'RB'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('court.', 'NN'),
#  ('”', 'JJ'),
#  ('Voters', 'NNP'),
#  ('approved', 'VBD'),
#  ('a', 'DT'),
#  ('separate', 'JJ'),
#  ('measure', 'NN'),
#  ('on', 'IN'),
#  ('Saturday', 'NNP'),
#  ('calling', 'VBG'),
#  ('for', 'IN'),
#  ('a', 'DT'),
#  ('“', 'JJ'),
#  ('different', 'JJ'),
#  ('process', 'NN'),
#  ('”', 'NN'),
#  ('to', 'TO'),
#  ('protect', 'VB'),
#  ('same-sex', 'JJ'),
#  ('unions', 'NNS'),
#  ('.', '.'),
#  ('It', 'PRP'),
#  ('is', 'VBZ'),
#  ('viewed', 'VBN'),
#  ('as', 'IN'),
#  ('an', 'DT'),
#  ('alternative', 'NN'),
#  ('to', 'TO'),
#  ('using', 'VBG'),
#  ('the', 'DT'),
#  ('civil', 'JJ'),
#  ('code', 'NN'),
#  ('.', '.'),
#  ('A', 'DT'),
#  ('third', 'JJ'),
#  ('initiative', 'NN'),
#  (',', ','),
#  ('also', 'RB'),
#  ('approved', 'VBN'),
#  (',', ','),
#  ('asked', 'VBD'),
#  ('that', 'IN'),
#  ('schools', 'NNS'),
#  ('avoid', 'VBP'),
#  ('teaching', 'VBG'),
#  ('LGBT', 'NNP'),
#  ('“', 'NNP'),
#  ('education', 'NN'),
#  ('”', 'NNP'),
#  ('.', '.'),
#  ('Amnesty', 'NNP'),
#  ('International', 'NNP'),
#  ('told', 'VBD'),
#  ('the', 'DT'),
#  ('government', 'NN'),
#  ('it', 'PRP'),
#  ('needed', 'VBD'),
#  ('to', 'TO'),
#  ('“', 'VB'),
#  ('deliver', 'NN'),
#  ('equality', 'NN'),
#  ('and', 'CC'),
#  ('dignity', 'NN'),
#  ('”', 'NNP'),
#  ('.', '.'),
#  ('“', 'VB'),
#  ('This', 'DT'),
#  ('result', 'NN'),
#  ('is', 'VBZ'),
#  ('a', 'DT'),
#  ('bitter', 'JJ'),
#  ('blow', 'NN'),
#  ('and', 'CC'),
#  ('a', 'DT'),
#  ('step', 'NN'),
#  ('backwards', 'NNS'),
#  ('for', 'IN'),
#  ('human', 'JJ'),
#  ('rights', 'NNS'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('Amnesty', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('Taiwan-based', 'JJ'),
#  ('acting', 'VBG'),
#  ('director', 'NN'),
#  (',', ','),
#  ('Annie', 'NNP'),
#  ('Huang', 'NNP'),
#  (',', ','),
#  ('said', 'VBD'),
#  ('.', '.'),
#  ('“', 'NN'),
#  ('However', 'RB'),
#  (',', ','),
#  ('despite', 'IN'),
#  ('this', 'DT'),
#  ('setback', 'NN'),
#  (',', ','),
#  ('we', 'PRP'),
#  ('remain', 'VBP'),
#  ('confident', 'JJ'),
#  ('that', 'IN'),
#  ('love', 'NN'),
#  ('and', 'CC'),
#  ('equality', 'NN'),
#  ('will', 'MD'),
#  ('ultimately', 'RB'),
#  ('prevail.', 'VB'),
#  ('”', 'NNP'),
#  ('Taiwanese', 'NNP'),
#  ('also', 'RB'),
#  ('elected', 'VBD'),
#  ('candidates', 'NNS'),
#  ('from', 'IN'),
#  ('the', 'DT'),
#  ('China-friendly', 'JJ'),
#  ('opposition', 'NN'),
#  ('Nationalist', 'NNP'),
#  ('party', 'NN'),
#  ('to', 'TO'),
#  ('a', 'DT'),
#  ('majority', 'NN'),
#  ('of', 'IN'),
#  ('mayoral', 'JJ'),
#  ('and', 'CC'),
#  ('county', 'JJ'),
#  ('magistrate', 'NN'),
#  ('posts', 'NNS'),
#  (',', ','),
#  ('reversing', 'VBG'),
#  ('the', 'DT'),
#  ('party', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('losses', 'NNS'),
#  ('in', 'IN'),
#  ('2014', 'CD'),
#  ('.', '.'),
#  ('Advertisement', 'NNP'),
#  ('China', 'NNP'),
#  ('welcomed', 'VBD'),
#  ('the', 'DT'),
#  ('defeat', 'NN'),
#  ('of', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('pro-independence', 'NN'),
#  ('ruling', 'NN'),
#  ('Democratic', 'JJ'),
#  ('Progressive', 'NNP'),
#  ('party', 'NN'),
#  ('(', '('),
#  ('DPP', 'NNP'),
#  (')', ')'),
#  ('at', 'IN'),
#  ('the', 'DT'),
#  ('local', 'JJ'),
#  ('elections', 'NNS'),
#  (',', ','),
#  ('saying', 'VBG'),
#  ('it', 'PRP'),
#  ('showed', 'VBD'),
#  ('people', 'NNS'),
#  ('wanted', 'VBD'),
#  ('peaceful', 'JJ'),
#  ('relations', 'NNS'),
#  ('with', 'IN'),
#  ('Beijing', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('vote', 'NN'),
#  ('dealt', 'VBD'),
#  ('a', 'DT'),
#  ('major', 'JJ'),
#  ('blow', 'NN'),
#  ('to', 'TO'),
#  ('President', 'NNP'),
#  ('Tsai', 'NNP'),
#  ('Ing-wen', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('hopes', 'NNS'),
#  ('of', 'IN'),
#  ('re-election', 'NN'),
#  ('in', 'IN'),
#  ('2020', 'CD'),
#  (',', ','),
#  ('forcing', 'VBG'),
#  ('her', 'PRP$'),
#  ('to', 'TO'),
#  ('quit', 'VB'),
#  ('as', 'IN'),
#  ('DPP', 'NNP'),
#  ('leader', 'NN'),
#  ('as', 'IN'),
#  ('the', 'DT'),
#  ('Beijing-friendly', 'NNP'),
#  ('main', 'JJ'),
#  ('opposition', 'NN'),
#  ('Kuomintang', 'NNP'),
#  ('(', '('),
#  ('KMT', 'NNP'),
#  (')', ')'),
#  ('made', 'VBD'),
#  ('gains', 'NNS'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('face', 'NN'),
#  ('of', 'IN'),
#  ('China', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('increasing', 'VBG'),
#  ('pressure', 'NN'),
#  ('on', 'IN'),
#  ('the', 'DT'),
#  ('island', 'NN'),
#  ('.', '.'),
#  ('Uncertainty', 'NNP'),
#  ('grips', 'VBZ'),
#  ('gay', 'JJ'),
#  ('people', 'NNS'),
#  ('in', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('as', 'IN'),
#  ('same-sex', 'JJ'),
#  ('marriage', 'NN'),
#  ('goes', 'VBZ'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('vote', 'NN'),
#  ('Read', 'NNP'),
#  ('more', 'RBR'),
#  ('The', 'DT'),
#  ('DPP', 'NNP'),
#  ('has', 'VBZ'),
#  ('been', 'VBN'),
#  ('left', 'VBN'),
#  ('in', 'IN'),
#  ('control', 'NN'),
#  ('of', 'IN'),
#  ('only', 'RB'),
#  ('six', 'CD'),
#  ('of', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'NN'),
#  ('cities', 'NNS'),
#  ('and', 'CC'),
#  ('counties', 'NNS'),
#  (',', ','),
#  ('compared', 'VBN'),
#  ('with', 'IN'),
#  ('at', 'IN'),
#  ('least', 'JJS'),
#  ('15', 'CD'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('KMT', 'NNP'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('losses', 'NNS'),
#  ('included', 'VBD'),
#  ('one', 'CD'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('most', 'JJS'),
#  ('steadfast', 'JJ'),
#  ('strongholds', 'NNS'),
#  (',', ','),
#  ('the', 'DT'),
#  ('southern', 'JJ'),
#  ('city', 'NN'),
#  ('of', 'IN'),
#  ('Kaohsiung', 'NNP'),
#  ('.', '.'),
#  ('“', 'VB'),
#  ('The', 'DT'),
#  ('[', 'JJ'),
#  ('election', 'NN'),
#  (']', 'NN'),
#  ('results', 'NNS'),
#  ('reflected', 'VBD'),
#  ('the', 'DT'),
#  ('strong', 'JJ'),
#  ('will', 'MD'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('Taiwan', 'NNP'),
#  ('public', 'NN'),
#  ('in', 'IN'),
#  ('hoping', 'VBG'),
#  ('to', 'TO'),
#  ('continue', 'VB'),
#  ('to', 'TO'),
#  ('share', 'NN'),
#  ('the', 'DT'),
#  ('benefits', 'NNS'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('peaceful', 'JJ'),
#  ('development', 'NN'),
#  ('of', 'IN'),
#  ('relations', 'NNS'),
#  ('across', 'IN'),
#  ('the', 'DT'),
#  ('Taiwan', 'NNP'),
#  ('Strait', 'NNP'),
#  (',', ','),
#  ('and', 'CC'),
#  ('their', 'PRP$'),
#  ('strong', 'JJ'),
#  ('wish', 'NN'),
#  ('in', 'IN'),
#  ('hoping', 'VBG'),
#  ('to', 'TO'),
#  ('improve', 'VB'),
#  ('the', 'DT'),
#  ('island', 'NN'),
#  ('’', 'NNP'),
#  ('s', 'VBZ'),
#  ('economy', 'NN'),
#  ('and', 'CC'),
#  ('people', 'NNS'),
#  ('’', 'VBP'),
#  ('s', 'JJ'),
#  ('wellbeing', 'NN'),
#  (',', ','),
#  ('”', 'NNP'),
#  ('said', 'VBD'),
#  ('a', 'DT'),
#  ('statement', 'NN'),
#  ('by', 'IN'),
#  ('China', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('policy-making', 'JJ'),
#  ('Taiwan', 'NNP'),
#  ('Affairs', 'NNPS'),
#  ('Office', 'NNP'),
#  ('and', 'CC'),
#  ('carried', 'VBN'),
#  ('by', 'IN'),
#  ('state', 'NN'),
#  ('media', 'NNS'),
#  ('.', '.'),
#  ('Tsai', 'NNP'),
#  ('and', 'CC'),
#  ('the', 'DT'),
#  ('DPP', 'NNP'),
#  ('have', 'VBP'),
#  ('faced', 'VBN'),
#  ('a', 'DT'),
#  ('mounting', 'VBG'),
#  ('backlash', 'NN'),
#  ('over', 'IN'),
#  ('domestic', 'JJ'),
#  ('reforms', 'NNS'),
#  ('as', 'RB'),
#  ('well', 'RB'),
#  ('as', 'IN'),
#  ('concerns', 'NNS'),
#  ('about', 'IN'),
#  ('deteriorating', 'VBG'),
#  ('ties', 'NNS'),
#  ('with', 'IN'),
#  ('China', 'NNP'),
#  (',', ','),
#  ('which', 'WDT'),
#  ('still', 'RB'),
#  ('sees', 'VBZ'),
#  ('self-ruling', 'JJ'),
#  ('Taiwan', 'NNP'),
#  ('as', 'IN'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('its', 'PRP$'),
#  ('territory', 'NN'),
#  ('to', 'TO'),
#  ('be', 'VB'),
#  ('reunified', 'VBN'),
#  ('.', '.'),
#  ('Tsai', 'NNP'),
#  ('told', 'VBD'),
#  ('reporters', 'NNS'),
#  ('that', 'IN'),
#  ('she', 'PRP'),
#  ('would', 'MD'),
#  ('take', 'VB'),
#  ('“', 'JJ'),
#  ('complete', 'JJ'),
#  ('responsibility', 'NN'),
#  ('”', 'NN'),
#  ('for', 'IN'),
#  ('the', 'DT'),
#  ('defeat', 'NN'),
#  ('as', 'IN'),
#  ('she', 'PRP'),
#  ('resigned', 'VBD'),
#  ('as', 'IN'),
#  ('chair', 'NN'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('party', 'NN'),
#  ('.', '.'),
#  ('Beijing', 'NNP'),
#  ('has', 'VBZ'),
#  ('intensified', 'VBN'),
#  ('pressure', 'NN'),
#  ('on', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('under', 'IN'),
#  ('Tsai', 'NNP'),
#  (',', ','),
#  ('upping', 'VBG'),
#  ('military', 'JJ'),
#  ('drills', 'NNS'),
#  (',', ','),
#  ('poaching', 'VBG'),
#  ('diplomatic', 'JJ'),
#  ('allies', 'NNS'),
#  ('and', 'CC'),
#  ('successfully', 'RB'),
#  ('convincing', 'JJ'),
#  ('international', 'JJ'),
#  ('businesses', 'NNS'),
#  ('to', 'TO'),
#  ('list', 'VB'),
#  ('the', 'DT'),
#  ('island', 'NN'),
#  ('as', 'IN'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('China', 'NNP'),
#  ('on', 'IN'),
#  ('their', 'PRP$'),
#  ('websites', 'NNS'),
#  ('.', '.'),
#  ('The', 'DT'),
#  ('DPP', 'NNP'),
#  ('is', 'VBZ'),
#  ('traditionally', 'RB'),
#  ('pro-independence', 'JJ'),
#  ('and', 'CC'),
#  ('Tsai', 'NNP'),
#  ('has', 'VBZ'),
#  ('refused', 'VBN'),
#  ('to', 'TO'),
#  ('acknowledge', 'VB'),
#  ('Beijing', 'NNP'),
#  ('’', 'NNP'),
#  ('s', 'VBD'),
#  ('stance', 'NN'),
#  ('that', 'IN'),
#  ('Taiwan', 'NNP'),
#  ('is', 'VBZ'),
#  ('part', 'NN'),
#  ('of', 'IN'),
#  ('“', 'NNP'),
#  ('one', 'CD'),
#  ('China', 'NNP'),
#  ('”', 'NNP'),
#  (',', ','),
#  ('unlike', 'IN'),
#  ('her', 'PRP$'),
#  ('KMT', 'NNP'),
#  ('predecessor', 'NN'),
#  (',', ','),
#  ('Ma', 'NNP'),
#  ('Ying-jeou', 'NNP'),
#  ('.', '.'),
#  ('Ahead', 'NNP'),
#  ('of', 'IN'),
#  ('the', 'DT'),
#  ('vote', 'NN'),
#  (',', ','),
#  ('Tsai', 'NNP'),
#  ('and', 'CC'),
#  ('DPP', 'NNP'),
#  ('officials', 'NNS'),
#  ('repeatedly', 'RB'),
#  ('accused', 'VBD'),
#  ('China', 'NNP'),
#  ('of', 'IN'),
#  ('meddling', 'VBG'),
#  ('in', 'IN'),
#  ('the', 'DT'),
#  ('lead-up', 'NN'),
#  ('to', 'TO'),
#  ('the', 'DT'),
#  ('elections', 'NNS'),
#  ('by', 'IN'),
#  ('operating', 'VBG'),
#  ('a', 'DT'),
#  ('“', 'JJ'),
#  ('fake', 'JJ'),
#  ('news', 'NN'),
#  ('”', 'NNP'),
#  ('campaign', 'NN'),
#  ('.', '.'),
#  ('Beijing', 'NNP'),
#  ('has', 'VBZ'),
#  ('denied', 'VBN'),
#  ('the', 'DT'),
#  ('allegations', 'NNS'),
#  ('.', '.')]

# %% [markdown]
# 自訂名詞片語 NP = 冠詞 DT + 任意數量的形容詞 JJ + 名詞 NN

# %%
pattern = 'NP: {<DT>?<JJ>*<NN>}'
cp = nltk.RegexpParser(pattern)
cs = cp.parse(sent)
print(cs)
# Out:
# (S
#   Voters/NNS
#   in/IN
#   Taiwan/NNP
#   have/VBP
#   rejected/VBN
#   (NP same-sex/JJ marriage/NN)
#   in/IN
#   (NP a/DT referendum/NN)
#   ,/,
#   (NP a/DT setback/NN)
#   to/TO
#   LGBT/NNP
#   couples/NNS
#   hoping/VBG
#   their/PRP$
#   (NP island/NN)
#   will/MD
#   be/VB
#   (NP the/DT first/JJ country/NN)
#   in/IN
#   Asia/NNP
#   to/TO
#   let/VB
#   same-sex/JJ
#   couples/NNS
#   (NP share/NN)
#   (NP child/JJ custody/NN)
#   and/CC
#   (NP insurance/NN)
#   benefits/NNS
#   ./.
#   (NP The/DT vote/NN)
#   on/IN
#   Saturday/NNP
#   ,/,
#   organised/VBN
#   by/IN
#   Christian/JJ
#   groups/NNS
#   that/WDT
#   make/VBP
#   up/RP
#   about/RB
#   5/CD
#   (NP %/NN)
#   of/IN
#   Taiwan/NNP
#   ’/NNP
#   s/POS
#   (NP population/NN)
#   and/CC
#   advocates/NNS
#   of/IN
#   (NP the/DT traditional/JJ Chinese/JJ family/NN)
#   (NP structure/NN)
#   ,/,
#   contradicts/VBZ
#   a/DT
#   May/NNP
#   2017/CD
#   (NP constitutional/JJ court/NN)
#   (NP ruling/NN)
#   ./.
#   Justices/NNS
#   told/VBD
#   legislators/NNS
#   then/RB
#   to/TO
#   make/VB
#   (NP same-sex/JJ marriage/NN)
#   legal/JJ
#   within/IN
#   two/CD
#   years/NNS
#   ,/,
#   a/DT
#   first/JJ
#   for/IN
#   Asia/NNP
#   ,/,
#   where/WRB
#   (NP religion/NN)
#   and/CC
#   conservative/JJ
#   governments/NNS
#   normally/RB
#   keep/VB
#   the/DT
#   bans/NNS
#   in/IN
#   (NP place/NN)
#   ./.
#   Although/IN
#   (NP the/DT ballot/NN)
#   is/VBZ
#   advisory/JJ
#   only/RB
#   ,/,
#   it/PRP
#   is/VBZ
#   expected/VBN
#   to/TO
#   frustrate/VB
#   lawmakers/NNS
#   mindful/JJ
#   of/IN
#   (NP public/JJ opinion/NN)
#   as/IN
#   they/PRP
#   face/VBP
#   (NP the/DT court/NN)
#   (NP deadline/NN)
#   (NP next/JJ year/NN)
#   ./.
#   Many/JJ
#   legislators/NNS
#   will/MD
#   stand/VB
#   for/IN
#   (NP re-election/NN)
#   in/IN
#   2020/CD
#   ./.
#   “/VB
#   (NP The/DT legislature/NN)
#   has/VBZ
#   lots/NNS
#   of/IN
#   choices/NNS
#   on/IN
#   how/WRB
#   to/TO
#   make/VB
#   (NP this/DT court/NN)
#   (NP order/NN)
#   take/VB
#   (NP effect/NN)
#   ,/,
#   ”/NNP
#   said/VBD
#   (NP referendum/JJ proponent/NN)
#   Chen/NNP
#   Ke/NNP
#   ,/,
#   a/DT
#   Catholic/NNP
#   (NP pastor/NN)
#   in/IN
#   Taiwan/NNP
#   and/CC
#   (NP an/DT opponent/NN)
#   of/IN
#   (NP same-sex/JJ marriage/NN)
#   ./.
#   Ruling/VBG
#   (NP party/NN)
#   lawmakers/NNS
#   backed/VBN
#   by/IN
#   (NP president/NN)
#   Tsai/NNP
#   Ing-wen/NNP
#   had/VBD
#   proposed/VBN
#   legalising/VBG
#   (NP same-sex/JJ marriage/NN)
#   in/IN
#   late/JJ
#   2016/CD
#   ,/,
#   but/CC
#   put/VBD
#   aside/RP
#   their/PRP$
#   ideas/NNS
#   to/TO
#   await/VB
#   (NP the/DT court/NN)
#   (NP hearing/NN)
#   ./.
#   (NP Opposition/NN)
#   to/TO
#   (NP same-sex/JJ marriage/NN)
#   crested/VBN
#   after/IN
#   (NP the/DT court/NN)
#   (NP ruling/NN)
#   ./.
#   Opponents/NNS
#   have/VBP
#   held/VBN
#   rallies/NNS
#   and/CC
#   mobilised/VBN
#   votes/NNS
#   online/VBP
#   ./.
#   Courts/NNS
#   will/MD
#   still/RB
#   consider/VB
#   (NP local/JJ marriage-licensing/NN)
#   offices/NNS
#   in/IN
#   (NP violation/NN)
#   of/IN
#   (NP the/DT law/NN)
#   if/IN
#   they/PRP
#   refuse/VBP
#   same-sex/JJ
#   couples/NNS
#   until/IN
#   May/NNP
#   2019/CD
#   ,/,
#   a/DT
#   Ministry/NNP
#   of/IN
#   Justice/NNP
#   (NP spokesperson/NN)
#   said/VBD
#   (NP last/JJ week/NN)
#   ./.
#   “/VB
#   (NP The/DT referendum/NN)
#   is/VBZ
#   (NP a/DT general/JJ survey/NN)
#   ,/,
#   it/PRP
#   doesn/VBZ
#   ’/JJ
#   t/NNS
#   have/VBP
#   very/RB
#   strong/JJ
#   legal/JJ
#   implications/NNS
#   ,/,
#   ”/NNP
#   said/VBD
#   Shiau/NNP
#   Hong-chi/NNP
#   ,/,
#   (NP a/DT professor/NN)
#   of/IN
#   (NP gender/NN)
#   studies/NNS
#   and/CC
#   communications/NNS
#   (NP management/NN)
#   at/IN
#   Shih-Hsin/NNP
#   University/NNP
#   in/IN
#   Taiwan/NNP
#   ./.
#   “/VB
#   One/CD
#   (NP way/NN)
#   or/CC
#   another/DT
#   it/PRP
#   has/VBZ
#   to/TO
#   go/VB
#   back/RB
#   to/TO
#   (NP the/DT court./NN)
#   ”/JJ
#   Voters/NNP
#   approved/VBD
#   (NP a/DT separate/JJ measure/NN)
#   on/IN
#   Saturday/NNP
#   calling/VBG
#   for/IN
#   (NP a/DT “/JJ different/JJ process/NN)
#   (NP ”/NN)
#   to/TO
#   protect/VB
#   same-sex/JJ
#   unions/NNS
#   ./.
#   It/PRP
#   is/VBZ
#   viewed/VBN
#   as/IN
#   (NP an/DT alternative/NN)
#   to/TO
#   using/VBG
#   (NP the/DT civil/JJ code/NN)
#   ./.
#   (NP A/DT third/JJ initiative/NN)
#   ,/,
#   also/RB
#   approved/VBN
#   ,/,
#   asked/VBD
#   that/IN
#   schools/NNS
#   avoid/VBP
#   teaching/VBG
#   LGBT/NNP
#   “/NNP
#   (NP education/NN)
#   ”/NNP
#   ./.
#   Amnesty/NNP
#   International/NNP
#   told/VBD
#   (NP the/DT government/NN)
#   it/PRP
#   needed/VBD
#   to/TO
#   “/VB
#   (NP deliver/NN)
#   (NP equality/NN)
#   and/CC
#   (NP dignity/NN)
#   ”/NNP
#   ./.
#   “/VB
#   (NP This/DT result/NN)
#   is/VBZ
#   (NP a/DT bitter/JJ blow/NN)
#   and/CC
#   (NP a/DT step/NN)
#   backwards/NNS
#   for/IN
#   human/JJ
#   rights/NNS
#   in/IN
#   Taiwan/NNP
#   ,/,
#   ”/NNP
#   Amnesty/NNP
#   ’/NNP
#   s/VBD
#   Taiwan-based/JJ
#   acting/VBG
#   (NP director/NN)
#   ,/,
#   Annie/NNP
#   Huang/NNP
#   ,/,
#   said/VBD
#   ./.
#   (NP “/NN)
#   However/RB
#   ,/,
#   despite/IN
#   (NP this/DT setback/NN)
#   ,/,
#   we/PRP
#   remain/VBP
#   confident/JJ
#   that/IN
#   (NP love/NN)
#   and/CC
#   (NP equality/NN)
#   will/MD
#   ultimately/RB
#   prevail./VB
#   ”/NNP
#   Taiwanese/NNP
#   also/RB
#   elected/VBD
#   candidates/NNS
#   from/IN
#   (NP the/DT China-friendly/JJ opposition/NN)
#   Nationalist/NNP
#   (NP party/NN)
#   to/TO
#   (NP a/DT majority/NN)
#   of/IN
#   mayoral/JJ
#   and/CC
#   (NP county/JJ magistrate/NN)
#   posts/NNS
#   ,/,
#   reversing/VBG
#   (NP the/DT party/NN)
#   ’/NNP
#   (NP s/NN)
#   losses/NNS
#   in/IN
#   2014/CD
#   ./.
#   Advertisement/NNP
#   China/NNP
#   welcomed/VBD
#   (NP the/DT defeat/NN)
#   of/IN
#   Taiwan/NNP
#   ’/NNP
#   s/VBD
#   (NP pro-independence/NN)
#   (NP ruling/NN)
#   Democratic/JJ
#   Progressive/NNP
#   (NP party/NN)
#   (/(
#   DPP/NNP
#   )/)
#   at/IN
#   the/DT
#   local/JJ
#   elections/NNS
#   ,/,
#   saying/VBG
#   it/PRP
#   showed/VBD
#   people/NNS
#   wanted/VBD
#   peaceful/JJ
#   relations/NNS
#   with/IN
#   Beijing/NNP
#   ./.
#   (NP The/DT vote/NN)
#   dealt/VBD
#   (NP a/DT major/JJ blow/NN)
#   to/TO
#   President/NNP
#   Tsai/NNP
#   Ing-wen/NNP
#   ’/NNP
#   s/VBD
#   hopes/NNS
#   of/IN
#   (NP re-election/NN)
#   in/IN
#   2020/CD
#   ,/,
#   forcing/VBG
#   her/PRP$
#   to/TO
#   quit/VB
#   as/IN
#   DPP/NNP
#   (NP leader/NN)
#   as/IN
#   the/DT
#   Beijing-friendly/NNP
#   (NP main/JJ opposition/NN)
#   Kuomintang/NNP
#   (/(
#   KMT/NNP
#   )/)
#   made/VBD
#   gains/NNS
#   in/IN
#   (NP the/DT face/NN)
#   of/IN
#   China/NNP
#   ’/NNP
#   s/VBD
#   increasing/VBG
#   (NP pressure/NN)
#   on/IN
#   (NP the/DT island/NN)
#   ./.
#   Uncertainty/NNP
#   grips/VBZ
#   gay/JJ
#   people/NNS
#   in/IN
#   Taiwan/NNP
#   as/IN
#   (NP same-sex/JJ marriage/NN)
#   goes/VBZ
#   to/TO
#   (NP the/DT vote/NN)
#   Read/NNP
#   more/RBR
#   The/DT
#   DPP/NNP
#   has/VBZ
#   been/VBN
#   left/VBN
#   in/IN
#   (NP control/NN)
#   of/IN
#   only/RB
#   six/CD
#   of/IN
#   Taiwan/NNP
#   ’/NNP
#   (NP s/NN)
#   cities/NNS
#   and/CC
#   counties/NNS
#   ,/,
#   compared/VBN
#   with/IN
#   at/IN
#   least/JJS
#   15/CD
#   for/IN
#   the/DT
#   KMT/NNP
#   ./.
#   The/DT
#   losses/NNS
#   included/VBD
#   one/CD
#   of/IN
#   its/PRP$
#   most/JJS
#   steadfast/JJ
#   strongholds/NNS
#   ,/,
#   (NP the/DT southern/JJ city/NN)
#   of/IN
#   Kaohsiung/NNP
#   ./.
#   “/VB
#   (NP The/DT [/JJ election/NN)
#   (NP ]/NN)
#   results/NNS
#   reflected/VBD
#   the/DT
#   strong/JJ
#   will/MD
#   of/IN
#   the/DT
#   Taiwan/NNP
#   (NP public/NN)
#   in/IN
#   hoping/VBG
#   to/TO
#   continue/VB
#   to/TO
#   (NP share/NN)
#   the/DT
#   benefits/NNS
#   of/IN
#   (NP the/DT peaceful/JJ development/NN)
#   of/IN
#   relations/NNS
#   across/IN
#   the/DT
#   Taiwan/NNP
#   Strait/NNP
#   ,/,
#   and/CC
#   their/PRP$
#   (NP strong/JJ wish/NN)
#   in/IN
#   hoping/VBG
#   to/TO
#   improve/VB
#   (NP the/DT island/NN)
#   ’/NNP
#   s/VBZ
#   (NP economy/NN)
#   and/CC
#   people/NNS
#   ’/VBP
#   (NP s/JJ wellbeing/NN)
#   ,/,
#   ”/NNP
#   said/VBD
#   (NP a/DT statement/NN)
#   by/IN
#   China/NNP
#   ’/NNP
#   s/VBD
#   policy-making/JJ
#   Taiwan/NNP
#   Affairs/NNPS
#   Office/NNP
#   and/CC
#   carried/VBN
#   by/IN
#   (NP state/NN)
#   media/NNS
#   ./.
#   Tsai/NNP
#   and/CC
#   the/DT
#   DPP/NNP
#   have/VBP
#   faced/VBN
#   a/DT
#   mounting/VBG
#   (NP backlash/NN)
#   over/IN
#   domestic/JJ
#   reforms/NNS
#   as/RB
#   well/RB
#   as/IN
#   concerns/NNS
#   about/IN
#   deteriorating/VBG
#   ties/NNS
#   with/IN
#   China/NNP
#   ,/,
#   which/WDT
#   still/RB
#   sees/VBZ
#   self-ruling/JJ
#   Taiwan/NNP
#   as/IN
#   (NP part/NN)
#   of/IN
#   its/PRP$
#   (NP territory/NN)
#   to/TO
#   be/VB
#   reunified/VBN
#   ./.
#   Tsai/NNP
#   told/VBD
#   reporters/NNS
#   that/IN
#   she/PRP
#   would/MD
#   take/VB
#   (NP “/JJ complete/JJ responsibility/NN)
#   (NP ”/NN)
#   for/IN
#   (NP the/DT defeat/NN)
#   as/IN
#   she/PRP
#   resigned/VBD
#   as/IN
#   (NP chair/NN)
#   of/IN
#   (NP the/DT party/NN)
#   ./.
#   Beijing/NNP
#   has/VBZ
#   intensified/VBN
#   (NP pressure/NN)
#   on/IN
#   Taiwan/NNP
#   under/IN
#   Tsai/NNP
#   ,/,
#   upping/VBG
#   military/JJ
#   drills/NNS
#   ,/,
#   poaching/VBG
#   diplomatic/JJ
#   allies/NNS
#   and/CC
#   successfully/RB
#   convincing/JJ
#   international/JJ
#   businesses/NNS
#   to/TO
#   list/VB
#   (NP the/DT island/NN)
#   as/IN
#   (NP part/NN)
#   of/IN
#   China/NNP
#   on/IN
#   their/PRP$
#   websites/NNS
#   ./.
#   The/DT
#   DPP/NNP
#   is/VBZ
#   traditionally/RB
#   pro-independence/JJ
#   and/CC
#   Tsai/NNP
#   has/VBZ
#   refused/VBN
#   to/TO
#   acknowledge/VB
#   Beijing/NNP
#   ’/NNP
#   s/VBD
#   (NP stance/NN)
#   that/IN
#   Taiwan/NNP
#   is/VBZ
#   (NP part/NN)
#   of/IN
#   “/NNP
#   one/CD
#   China/NNP
#   ”/NNP
#   ,/,
#   unlike/IN
#   her/PRP$
#   KMT/NNP
#   (NP predecessor/NN)
#   ,/,
#   Ma/NNP
#   Ying-jeou/NNP
#   ./.
#   Ahead/NNP
#   of/IN
#   (NP the/DT vote/NN)
#   ,/,
#   Tsai/NNP
#   and/CC
#   DPP/NNP
#   officials/NNS
#   repeatedly/RB
#   accused/VBD
#   China/NNP
#   of/IN
#   meddling/VBG
#   in/IN
#   (NP the/DT lead-up/NN)
#   to/TO
#   the/DT
#   elections/NNS
#   by/IN
#   operating/VBG
#   (NP a/DT “/JJ fake/JJ news/NN)
#   ”/NNP
#   (NP campaign/NN)
#   ./.
#   Beijing/NNP
#   has/VBZ
#   denied/VBN
#   the/DT
#   allegations/NNS
#   ./.)

# %%
tree1 = nltk.Tree('NP',['Alick'])
print(tree1)
tree2 = nltk.Tree('N',['Alick','Rabbit'])
print(tree2)
tree3 = nltk.Tree('S',[tree1,tree2])
print(tree3.label())
tree3.draw()
# Out:
# (NP Alick)
# (N Alick Rabbit)
# S

# %%
NER = ne_chunk(nltk.pos_tag(word_tokenize(strEx)), binary=False)

# %%
type(NER)
# Out:
# nltk.tree.Tree

# %%
print(NER)
# Out:
# (S
#   Voters/NNS
#   in/IN
#   (GPE Taiwan/NNP)
#   have/VBP
#   rejected/VBN
#   same-sex/JJ
#   marriage/NN
#   in/IN
#   a/DT
#   referendum/NN
#   ,/,
#   a/DT
#   setback/NN
#   to/TO
#   (ORGANIZATION LGBT/NNP)
#   couples/NNS
#   hoping/VBG
#   their/PRP$
#   island/NN
#   will/MD
#   be/VB
#   the/DT
#   first/JJ
#   country/NN
#   in/IN
#   (GPE Asia/NNP)
#   to/TO
#   let/VB
#   same-sex/JJ
#   couples/NNS
#   share/NN
#   child/JJ
#   custody/NN
#   and/CC
#   insurance/NN
#   benefits/NNS
#   ./.
#   The/DT
#   vote/NN
#   on/IN
#   Saturday/NNP
#   ,/,
#   organised/VBN
#   by/IN
#   (GPE Christian/JJ)
#   groups/NNS
#   that/WDT
#   make/VBP
#   up/RP
#   about/RB
#   5/CD
#   %/NN
#   of/IN
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/POS
#   population/NN
#   and/CC
#   advocates/NNS
#   of/IN
#   the/DT
#   traditional/JJ
#   (GPE Chinese/JJ)
#   family/NN
#   structure/NN
#   ,/,
#   contradicts/VBZ
#   a/DT
#   May/NNP
#   2017/CD
#   constitutional/JJ
#   court/NN
#   ruling/NN
#   ./.
#   (PERSON Justices/NNS)
#   told/VBD
#   legislators/NNS
#   then/RB
#   to/TO
#   make/VB
#   same-sex/JJ
#   marriage/NN
#   legal/JJ
#   within/IN
#   two/CD
#   years/NNS
#   ,/,
#   a/DT
#   first/JJ
#   for/IN
#   (GPE Asia/NNP)
#   ,/,
#   where/WRB
#   religion/NN
#   and/CC
#   conservative/JJ
#   governments/NNS
#   normally/RB
#   keep/VB
#   the/DT
#   bans/NNS
#   in/IN
#   place/NN
#   ./.
#   Although/IN
#   the/DT
#   ballot/NN
#   is/VBZ
#   advisory/JJ
#   only/RB
#   ,/,
#   it/PRP
#   is/VBZ
#   expected/VBN
#   to/TO
#   frustrate/VB
#   lawmakers/NNS
#   mindful/JJ
#   of/IN
#   public/JJ
#   opinion/NN
#   as/IN
#   they/PRP
#   face/VBP
#   the/DT
#   court/NN
#   deadline/NN
#   next/JJ
#   year/NN
#   ./.
#   Many/JJ
#   legislators/NNS
#   will/MD
#   stand/VB
#   for/IN
#   re-election/NN
#   in/IN
#   2020/CD
#   ./.
#   “/VB
#   The/DT
#   legislature/NN
#   has/VBZ
#   lots/NNS
#   of/IN
#   choices/NNS
#   on/IN
#   how/WRB
#   to/TO
#   make/VB
#   this/DT
#   court/NN
#   order/NN
#   take/VB
#   effect/NN
#   ,/,
#   ”/NNP
#   said/VBD
#   referendum/JJ
#   proponent/NN
#   (PERSON Chen/NNP Ke/NNP)
#   ,/,
#   a/DT
#   (ORGANIZATION Catholic/NNP)
#   pastor/NN
#   in/IN
#   (GPE Taiwan/NNP)
#   and/CC
#   an/DT
#   opponent/NN
#   of/IN
#   same-sex/JJ
#   marriage/NN
#   ./.
#   Ruling/VBG
#   party/NN
#   lawmakers/NNS
#   backed/VBN
#   by/IN
#   president/NN
#   (PERSON Tsai/NNP Ing-wen/NNP)
#   had/VBD
#   proposed/VBN
#   legalising/VBG
#   same-sex/JJ
#   marriage/NN
#   in/IN
#   late/JJ
#   2016/CD
#   ,/,
#   but/CC
#   put/VBD
#   aside/RP
#   their/PRP$
#   ideas/NNS
#   to/TO
#   await/VB
#   the/DT
#   court/NN
#   hearing/NN
#   ./.
#   Opposition/NN
#   to/TO
#   same-sex/JJ
#   marriage/NN
#   crested/VBN
#   after/IN
#   the/DT
#   court/NN
#   ruling/NN
#   ./.
#   Opponents/NNS
#   have/VBP
#   held/VBN
#   rallies/NNS
#   and/CC
#   mobilised/VBN
#   votes/NNS
#   online/VBP
#   ./.
#   Courts/NNS
#   will/MD
#   still/RB
#   consider/VB
#   local/JJ
#   marriage-licensing/NN
#   offices/NNS
#   in/IN
#   violation/NN
#   of/IN
#   the/DT
#   law/NN
#   if/IN
#   they/PRP
#   refuse/VBP
#   same-sex/JJ
#   couples/NNS
#   until/IN
#   May/NNP
#   2019/CD
#   ,/,
#   a/DT
#   (ORGANIZATION Ministry/NNP)
#   of/IN
#   (ORGANIZATION Justice/NNP)
#   spokesperson/NN
#   said/VBD
#   last/JJ
#   week/NN
#   ./.
#   “/VB
#   The/DT
#   referendum/NN
#   is/VBZ
#   a/DT
#   general/JJ
#   survey/NN
#   ,/,
#   it/PRP
#   doesn/VBZ
#   ’/JJ
#   t/NNS
#   have/VBP
#   very/RB
#   strong/JJ
#   legal/JJ
#   implications/NNS
#   ,/,
#   ”/NNP
#   said/VBD
#   (PERSON Shiau/NNP Hong-chi/NNP)
#   ,/,
#   a/DT
#   professor/NN
#   of/IN
#   gender/NN
#   studies/NNS
#   and/CC
#   communications/NNS
#   management/NN
#   at/IN
#   (ORGANIZATION Shih-Hsin/NNP University/NNP)
#   in/IN
#   (GPE Taiwan/NNP)
#   ./.
#   “/VB
#   One/CD
#   way/NN
#   or/CC
#   another/DT
#   it/PRP
#   has/VBZ
#   to/TO
#   go/VB
#   back/RB
#   to/TO
#   the/DT
#   court./NN
#   ”/JJ
#   Voters/NNP
#   approved/VBD
#   a/DT
#   separate/JJ
#   measure/NN
#   on/IN
#   Saturday/NNP
#   calling/VBG
#   for/IN
#   a/DT
#   “/JJ
#   different/JJ
#   process/NN
#   ”/NN
#   to/TO
#   protect/VB
#   same-sex/JJ
#   unions/NNS
#   ./.
#   It/PRP
#   is/VBZ
#   viewed/VBN
#   as/IN
#   an/DT
#   alternative/NN
#   to/TO
#   using/VBG
#   the/DT
#   civil/JJ
#   code/NN
#   ./.
#   A/DT
#   third/JJ
#   initiative/NN
#   ,/,
#   also/RB
#   approved/VBN
#   ,/,
#   asked/VBD
#   that/IN
#   schools/NNS
#   avoid/VBP
#   teaching/VBG
#   (ORGANIZATION LGBT/NNP)
#   “/NNP
#   education/NN
#   ”/NNP
#   ./.
#   (PERSON Amnesty/NNP International/NNP)
#   told/VBD
#   the/DT
#   government/NN
#   it/PRP
#   needed/VBD
#   to/TO
#   “/VB
#   deliver/NN
#   equality/NN
#   and/CC
#   dignity/NN
#   ”/NNP
#   ./.
#   “/VB
#   This/DT
#   result/NN
#   is/VBZ
#   a/DT
#   bitter/JJ
#   blow/NN
#   and/CC
#   a/DT
#   step/NN
#   backwards/NNS
#   for/IN
#   human/JJ
#   rights/NNS
#   in/IN
#   (GPE Taiwan/NNP)
#   ,/,
#   ”/NNP
#   (PERSON Amnesty/NNP)
#   ’/NNP
#   s/VBD
#   Taiwan-based/JJ
#   acting/VBG
#   director/NN
#   ,/,
#   (PERSON Annie/NNP Huang/NNP)
#   ,/,
#   said/VBD
#   ./.
#   “/NN
#   However/RB
#   ,/,
#   despite/IN
#   this/DT
#   setback/NN
#   ,/,
#   we/PRP
#   remain/VBP
#   confident/JJ
#   that/IN
#   love/NN
#   and/CC
#   equality/NN
#   will/MD
#   ultimately/RB
#   prevail./VB
#   ”/NNP
#   Taiwanese/NNP
#   also/RB
#   elected/VBD
#   candidates/NNS
#   from/IN
#   the/DT
#   China-friendly/JJ
#   opposition/NN
#   (ORGANIZATION Nationalist/NNP)
#   party/NN
#   to/TO
#   a/DT
#   majority/NN
#   of/IN
#   mayoral/JJ
#   and/CC
#   county/JJ
#   magistrate/NN
#   posts/NNS
#   ,/,
#   reversing/VBG
#   the/DT
#   party/NN
#   ’/NNP
#   s/NN
#   losses/NNS
#   in/IN
#   2014/CD
#   ./.
#   Advertisement/NNP
#   (GPE China/NNP)
#   welcomed/VBD
#   the/DT
#   defeat/NN
#   of/IN
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/VBD
#   pro-independence/NN
#   ruling/NN
#   (ORGANIZATION Democratic/JJ Progressive/NNP)
#   party/NN
#   (/(
#   (ORGANIZATION DPP/NNP)
#   )/)
#   at/IN
#   the/DT
#   local/JJ
#   elections/NNS
#   ,/,
#   saying/VBG
#   it/PRP
#   showed/VBD
#   people/NNS
#   wanted/VBD
#   peaceful/JJ
#   relations/NNS
#   with/IN
#   (GPE Beijing/NNP)
#   ./.
#   The/DT
#   vote/NN
#   dealt/VBD
#   a/DT
#   major/JJ
#   blow/NN
#   to/TO
#   President/NNP
#   (PERSON Tsai/NNP)
#   Ing-wen/NNP
#   ’/NNP
#   s/VBD
#   hopes/NNS
#   of/IN
#   re-election/NN
#   in/IN
#   2020/CD
#   ,/,
#   forcing/VBG
#   her/PRP$
#   to/TO
#   quit/VB
#   as/IN
#   (ORGANIZATION DPP/NNP)
#   leader/NN
#   as/IN
#   the/DT
#   Beijing-friendly/NNP
#   main/JJ
#   opposition/NN
#   (PERSON Kuomintang/NNP)
#   (/(
#   (ORGANIZATION KMT/NNP)
#   )/)
#   made/VBD
#   gains/NNS
#   in/IN
#   the/DT
#   face/NN
#   of/IN
#   (GPE China/NNP)
#   ’/NNP
#   s/VBD
#   increasing/VBG
#   pressure/NN
#   on/IN
#   the/DT
#   island/NN
#   ./.
#   (PERSON Uncertainty/NNP)
#   grips/VBZ
#   gay/JJ
#   people/NNS
#   in/IN
#   (GPE Taiwan/NNP)
#   as/IN
#   same-sex/JJ
#   marriage/NN
#   goes/VBZ
#   to/TO
#   the/DT
#   vote/NN
#   Read/NNP
#   more/RBR
#   The/DT
#   (ORGANIZATION DPP/NNP)
#   has/VBZ
#   been/VBN
#   left/VBN
#   in/IN
#   control/NN
#   of/IN
#   only/RB
#   six/CD
#   of/IN
#   (GPE Taiwan/NNP)
#   ’/NNP
#   s/NN
#   cities/NNS
#   and/CC
#   counties/NNS
#   ,/,
#   compared/VBN
#   with/IN
#   at/IN
#   least/JJS
#   15/CD
#   for/IN
#   the/DT
#   (ORGANIZATION KMT/NNP)
#   ./.
#   The/DT
#   losses/NNS
#   included/VBD
#   one/CD
#   of/IN
#   its/PRP$
#   most/JJS
#   steadfast/JJ
#   strongholds/NNS
#   ,/,
#   the/DT
#   southern/JJ
#   city/NN
#   of/IN
#   (GPE Kaohsiung/NNP)
#   ./.
#   “/VB
#   The/DT
#   [/JJ
#   election/NN
#   ]/NN
#   results/NNS
#   reflected/VBD
#   the/DT
#   strong/JJ
#   will/MD
#   of/IN
#   the/DT
#   (GPE Taiwan/NNP)
#   public/NN
#   in/IN
#   hoping/VBG
#   to/TO
#   continue/VB
#   to/TO
#   share/NN
#   the/DT
#   benefits/NNS
#   of/IN
#   the/DT
#   peaceful/JJ
#   development/NN
#   of/IN
#   relations/NNS
#   across/IN
#   the/DT
#   (GPE Taiwan/NNP Strait/NNP)
#   ,/,
#   and/CC
#   their/PRP$
#   strong/JJ
#   wish/NN
#   in/IN
#   hoping/VBG
#   to/TO
#   improve/VB
#   the/DT
#   island/NN
#   ’/NNP
#   s/VBZ
#   economy/NN
#   and/CC
#   people/NNS
#   ’/VBP
#   s/JJ
#   wellbeing/NN
#   ,/,
#   ”/NNP
#   said/VBD
#   a/DT
#   statement/NN
#   by/IN
#   (GPE China/NNP)
#   ’/NNP
#   s/VBD
#   policy-making/JJ
#   (GPE Taiwan/NNP)
#   Affairs/NNPS
#   Office/NNP
#   and/CC
#   carried/VBN
#   by/IN
#   state/NN
#   media/NNS
#   ./.
#   (PERSON Tsai/NNP)
#   and/CC
#   the/DT
#   (ORGANIZATION DPP/NNP)
#   have/VBP
#   faced/VBN
#   a/DT
#   mounting/VBG
#   backlash/NN
#   over/IN
#   domestic/JJ
#   reforms/NNS
#   as/RB
#   well/RB
#   as/IN
#   concerns/NNS
#   about/IN
#   deteriorating/VBG
#   ties/NNS
#   with/IN
#   (GPE China/NNP)
#   ,/,
#   which/WDT
#   still/RB
#   sees/VBZ
#   self-ruling/JJ
#   (GPE Taiwan/NNP)
#   as/IN
#   part/NN
#   of/IN
#   its/PRP$
#   territory/NN
#   to/TO
#   be/VB
#   reunified/VBN
#   ./.
#   (PERSON Tsai/NNP)
#   told/VBD
#   reporters/NNS
#   that/IN
#   she/PRP
#   would/MD
#   take/VB
#   “/JJ
#   complete/JJ
#   responsibility/NN
#   ”/NN
#   for/IN
#   the/DT
#   defeat/NN
#   as/IN
#   she/PRP
#   resigned/VBD
#   as/IN
#   chair/NN
#   of/IN
#   the/DT
#   party/NN
#   ./.
#   (GPE Beijing/NNP)
#   has/VBZ
#   intensified/VBN
#   pressure/NN
#   on/IN
#   (GPE Taiwan/NNP)
#   under/IN
#   (PERSON Tsai/NNP)
#   ,/,
#   upping/VBG
#   military/JJ
#   drills/NNS
#   ,/,
#   poaching/VBG
#   diplomatic/JJ
#   allies/NNS
#   and/CC
#   successfully/RB
#   convincing/JJ
#   international/JJ
#   businesses/NNS
#   to/TO
#   list/VB
#   the/DT
#   island/NN
#   as/IN
#   part/NN
#   of/IN
#   (GPE China/NNP)
#   on/IN
#   their/PRP$
#   websites/NNS
#   ./.
#   The/DT
#   (ORGANIZATION DPP/NNP)
#   is/VBZ
#   traditionally/RB
#   pro-independence/JJ
#   and/CC
#   (PERSON Tsai/NNP)
#   has/VBZ
#   refused/VBN
#   to/TO
#   acknowledge/VB
#   (GPE Beijing/NNP)
#   ’/NNP
#   s/VBD
#   stance/NN
#   that/IN
#   (GPE Taiwan/NNP)
#   is/VBZ
#   part/NN
#   of/IN
#   “/NNP
#   one/CD
#   (GPE China/NNP)
#   ”/NNP
#   ,/,
#   unlike/IN
#   her/PRP$
#   (ORGANIZATION KMT/NNP)
#   predecessor/NN
#   ,/,
#   (PERSON Ma/NNP)
#   Ying-jeou/NNP
#   ./.
#   Ahead/NNP
#   of/IN
#   the/DT
#   vote/NN
#   ,/,
#   (PERSON Tsai/NNP)
#   and/CC
#   (ORGANIZATION DPP/NNP)
#   officials/NNS
#   repeatedly/RB
#   accused/VBD
#   (GPE China/NNP)
#   of/IN
#   meddling/VBG
#   in/IN
#   the/DT
#   lead-up/NN
#   to/TO
#   the/DT
#   elections/NNS
#   by/IN
#   operating/VBG
#   a/DT
#   “/JJ
#   fake/JJ
#   news/NN
#   ”/NNP
#   campaign/NN
#   ./.
#   (GPE Beijing/NNP)
#   has/VBZ
#   denied/VBN
#   the/DT
#   allegations/NNS
#   ./.)

# %%
def get_continuous_chunks(text, label):
    chunked = ne_chunk(pos_tag(word_tokenize(text)))
    prev = None
    continuous_chunk = []
    current_chunk = []

    for subtree in chunked:
        if type(subtree) == Tree and subtree.label() == label:
            current_chunk.append(" ".join([token for token, pos in subtree.leaves()]))
        elif current_chunk:
            named_entity = " ".join(current_chunk)
            if named_entity not in continuous_chunk:
                continuous_chunk.append(named_entity)
                current_chunk = []
        else:
            continue

    return continuous_chunk

# %%
get_continuous_chunks(strEx, 'GPE')
# Out:
# ['Taiwan',
#  'Asia',
#  'Christian',
#  'Taiwan Chinese',
#  'Asia Taiwan',
#  'Taiwan Taiwan',
#  'China',
#  'Taiwan Beijing',
#  'China Taiwan',
#  'Taiwan Kaohsiung',
#  'Taiwan Taiwan Strait',
#  'China Taiwan China',
#  'Taiwan Beijing Taiwan',
#  'China Beijing',
#  'Taiwan China']

# %%
get_continuous_chunks(strEx, 'ORGANIZATION')
# Out:
# ['LGBT',
#  'Catholic',
#  'Ministry',
#  'Justice',
#  'Shih-Hsin University',
#  'LGBT Nationalist',
#  'Democratic Progressive',
#  'DPP',
#  'DPP KMT',
#  'DPP KMT DPP']
